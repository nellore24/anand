# %% [markdown]
# 1.	Write a Python Program to Check if a Number is Positive, Negative or Zero?

# %%
def find():
    a=float(input("Enter number:"))
    if a>=0:
            print(a, "It is a positive number")
    elif a==5:
            print(a,"This is also positive number")

    else:
            print("Please enter positive number")

# %%
find()
# Out:
# Enter number: 8
# 8.0 It is a positive number

# %%
def find():
    a=float(input("Enter number:"))
    if a>=0:
            print(a, "It is a positive number")
    elif a==5:
            print(a,"This is also positive number")

    else:
            print("Please enter negatgive number")

# %%
find()
# Out:
# Enter number: -2
# Please enter negatgive number

# %%
def find():
    a=float(input("Enter number:"))
    if a>=10:
            print(a, "It is a positive number")
    elif a==0:
            print(a,"This is zero")

    else:
            print("Please enter positive number")

# %%
find()
# Out:
# Enter number: 0
# 0.0 This is zero

# %% [markdown]
# 2.	Write a Python Program to Check if a Number is Odd or Even?

# %%
a=float(input("Enter number:"))
b=a%2
if b==0:
              print("It is Even number")
elif b!=int():   
    print("it is ood")
else:
              print("It is Odd number:")
# Out:
# Enter number: 8
# It is Even number

# %%
a=float(input("Enter number:"))
b=a%2
if b==0:
              print("It is Even number:",a)
else:
              print("It is Odd number")
# Out:
# Enter number: 9
# It is Odd number

# %% [markdown]
# 3.	Write a Python Program to Check Leap Year?

# %%
year = int(input("Enter Year: "))

if year % 4 == 0 and year % 100 != 0:
    print(year, "is a Leap Year")
elif year % 100 == 0:
    print(year, "is not a Leap Year")
elif year % 400 ==0:
    print(year, "is a Leap Year")
else:
    print(year, "is not a Leap Year")
# Out:
# Enter Year:  4
# 4 is a Leap Year

# %% [markdown]
# 4.	Write a Python Program to Check Prime Number?

# %%
num = 29
flag = False

if num > 1:
    for i in range(2, num):
        if (num % i) == 0:
            flag = True
            break

if flag:
    print(num, "is not a prime number")
else:
    print(num, "is a prime number")
# Out:
# 29 is a prime number

# %% [markdown]
# 5.	Write a Python Program to Print all Prime Numbers in an Interval of 1-10000?

# %%
lower = 900
upper = 1000

print("Prime numbers between", lower, "and", upper, "are:")

for num in range(lower, upper + 1):
   # all prime numbers are greater than 1
   if num > 1:
       for i in range(2, num):
           if (num % i) == 0:
               break
       else:
           print(num)
# Out:
# Prime numbers between 900 and 1000 are:
# 907
# 911
# 919
# 929
# 937
# 941
# 947
# 953
# 967
# 971
# 977
# 983
# 991
# 997
