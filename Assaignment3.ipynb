# %% [raw]
# 1. Why are functions advantageous to have in your programs?

# %% [raw]
# Ans. No need to write a duplicate code.So program would be shoter. Easy to          update many values in function call and easy to read a code.

# %% [raw]
# 2. When does the code in a function run: when it's specified or when it's          called?

# %% [raw]
# Ans.The code in a function excutes when function is called. not when the           function is specified.

# %% [raw]
# 3. What statement creates a function?

# %% [raw]
# Ans. The def statement defines a function.

# %% [raw]
# 4. What is the difference between a function and a function call?

# %% [raw]
# Ans. A function is name which placed after def statement.So we need def              statement to define a function name.
#
#     Function call means a function name in which we pass some values. So values     gonna evalueates as per logic in def block of code and it return results.

# %% [raw]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %% [raw]
# Ans.One global scope and one local scope.

# %% [raw]
# 6. What happens to variables in a local scope when the function call returns?

# %% [raw]
# Ans. Then local scope is ignored and all variables in it are forgotten.

# %% [raw]
# 7. What is the concept of a return value? Is it possible to have a return value    in an expression?

# %% [raw]
# Ans. A return values is the value that a function call evaluates a like values.
#      A return values is a part of an expression.

# %% [raw]
# 8. If a function does not have a return statement, what is the return value of    a call to that function?

# %% [raw]
# Ans. If there is no return statement for a function, its return values is None.

# %% [raw]
# 9. How do you make a function variable refer to the global variable?

# %% [raw]
# Ans. We can use the global keyword to declare which variables are global.

# %% [raw]
# 10. What is the data type of None?

# %% [raw]
# Ans. The data type of None is NoneType.

# %% [raw]
# 11. What does the sentence import areallyourpetsnamederic do?

# %% [raw]
# Ans. using import statement imports a module name is areallyourpetsnamederic.

# %% [raw]
# 12. If you had a bacon() feature in a spam module, what would you call it after     importing spam?

# %% [raw]
# Ans. spam.bacon().

# %% [raw]
# 13. What can you do to save a programme from crashing if it encounters an           error?

# %% [raw]
# Ans. can put that in try clause in order to avoid a error.

# %% [raw]
# 14. What is the purpose of the try clause? What is the purpose of the except       clause?

# %% [raw]
# Ans.Possiblity of code is error then we put in try clause. If code got error it      excutes the except clause.
